# %% [markdown]
# <a href="https://colab.research.google.com/github/Awais-182/My-Python-Projects/blob/main/basic-arithmetic-calculator/v5_floor_division.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🧮 Basic Arithmetic Calculator – Version 7: Floor Division
#
# * **Repository Directory:** `basic-arithmetic-calculator`
# * **Notebook File:** `calculator_v5_floor_division.ipynb`
# * **Version:** `v5.0`
# * **Author:** Awais
# * **Language:** Python 3
#
# ## 📌 Program Description
# This program is the seventh entry in the **Basic Arithmetic Calculator** series within the `python-program-vault`.
#
# ### 🎯 Objectives:
# 1. Accept two numeric inputs from the user via the console.
# 2. Convert user input into Python integer variables.
# 3. Perform a floor division operation (`//`) on the stored numbers.
# 4. Output the integer quotient (truncated decimal) formatted clearly to the screen.

# %% [markdown]
# ## 📥 Step 1: Input Acquisition
#
# ### Explanation:
# * We use the built-in `input()` function to prompt the user for input.
# * Since `input()` returns string data, we wrap it in `int()` to convert the characters into mathematical integers.
# * The first number represents the **dividend** (numerator) and the second represents the **divisor** (denominator).
#
# ### Code Snippet:
# ```python
# first_num = int(input("Enter The First Number: "))
# second_num = int(input("Enter The Second Number: "))

# %% [markdown]
# ***
#
# ### Step 2 – Floor Division Execution**
#
# ```markdown
# ## ⚙️ Step 2: Floor Division Execution
#
# ### Explanation:
# * We apply the double forward slash operator (`//`) to perform integer floor division.
# * **Note on Behavior:** Unlike standard division (`/`), the `//` operator divides the numbers and **rounds DOWN** to the nearest whole integer, discarding any fractional or decimal portion (e.g., `7 // 2` evaluates to `3`).
#
# ### Code Snippet:
# ```python
# result = first_num // second_num

# %% [markdown]
# ***
#
# ### **TEXT CELL 4: Step 3 – Result Display**
#
# ```markdown
# ## 📤 Step 3: Result Display
#
# ### Explanation:
# * We pass static text and variables to the `print()` function to display the calculated result clearly to the user.
#
# ### Code Snippet:
# ```python
# print("Your result is:", result)

# %%
# Building a program where user will choose two numbers upon which floor division will be performed (first number will be dividedn and second will be divisor)
first_num=int(input("Enter The First Number: "))
second_num=int(input("Enter The Second Number: "))
result=first_num//second_num
print("Your result is:",result)
# Out:
# Enter The First Number: 9
# Enter The Second Number: 2
# Your result is: 4

# %% [markdown]
# ## ⚠️ Known Limitations & Design Constraints
#
# | Issue / Constraint | Technical Reason | Future Version Fix |
# | :--- | :--- | :--- |
# | **Decimal Input Crash** | `int()` strictly expects string representation of whole numbers. Passing floats (e.g., `5.5`) raises a `ValueError`. | Implement `float()` type conversion. |
# | **Division by Zero Crash** | Inputting `0` for `second_num` triggers a fatal `ZeroDivisionError`. | Implement `if/else` checks or `try-except` blocks. |
# | **Single-Run Lifetime** | Script terminates immediately after step 3. | Wrap logic inside a `while` loop for continuous calculations. |
# | **Decimal Truncation** | Discards all remainders and fractional values, which may cause precision loss for non-even divisions. | Use standard division (`/`) or modulo (`%`) alongside floor division. |
